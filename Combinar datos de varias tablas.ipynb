# %% [markdown]
# # CONCATENAR EN PANDAS

# %%
# importar librerias

# %% [markdown]
# ## 1. CONCATENAR DATASERIES (CONCAT)

# %%
# Creación de dataseries
serie_1 = pd.Series(['A', 'B', 'C'], index=[1, 2, 3])
serie_2 = pd.Series(['D', 'E', 'F'], index=[4, 5, 6])

# %%
# Concatenar dataseries
df_c = pd.concat([serie_1, serie_2])

# %%
df_c

# %% [markdown]
# ## 2. CONCATENAR DATAFRAMES

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %%
# Crear DataFrames del personal
Personal = pd.DataFrame([{'Nombre': 'Maria', 'Empleo': 'Directora'},
                         {'Nombre': 'Pepe', 'Empleo': 'Profesor'},
                         {'Nombre': 'Manuel', 'Empleo': 'Monitor'}])
# indexamos por nombre

# %%
# Crear Dataframe de estudiantes
estudiantes = pd.DataFrame([{'Nombre': 'Manuel', 'Facultad': 'Negocios'},
                           {'Nombre': 'Miguel', 'Facultad': 'Leyes'},
                           {'Nombre': 'Fernanda', 'Facultad': 'ingenieria'}])
# indexamos por nombre

# %% [markdown]
# ### 2.1 METODO CONCAT (outer)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Concatenar por filas

# %%
# Concatenar por columnas

# %% [markdown]
# ### 2.2 METODO CONCAT (inner)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# función inner

# %% [markdown]
# ## 3. APLICAR CONCAT A SERIES TEMPORALES

# %%
# Cargar datos no2

# %%
# Filtrar por columnas

# %%
# Visualizar datos

# %%
# Cargar datos no2

# %%
# Filtrar por columnas

# %%
# Visualizar datos

# %% [markdown]
# ## 3.1 Concatenar objetos por filas o por columnas

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Combinar las medidas de NO2 y PM25

# %%
# Función concat

# %%
# Visualizar datos

# %%
# Función shape

# %%
# Ordenar datos por indice

# %%
#visualizar datos

# %% [markdown]
# ## 3.2 Keys

# %%
# concatenar por el método Keys

# %%
# Visualizar datos
